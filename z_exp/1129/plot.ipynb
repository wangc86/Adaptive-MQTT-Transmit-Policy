# %%
#cdf
import numpy as np
import matplotlib.pyplot as plt

dir='/home/maggie/mosq2.0.12/1129mosq_bro_time/z_exp/1129/1205-4'

data = np.loadtxt(dir+'/result_end2end.txt.prev',dtype='float')/1000000
x1 = np.sort(data[:49])
y1 = 1. * np.arange(len(x1))/(len(x1)-1)

x2 = np.sort(data[50:])
y2 = 1. * np.arange(len(x2))/(len(x2)-1)


# data = np.loadtxt(dir+'/result_inBro.txt.prev',dtype='float')/1000000
# x2 = np.sort(data)
# y2 = 1. * np.arange(len(data))/(len(data)-1)

dir='/home/maggie/mosq2.0.12/1129mosq_bro_time/z_exp/1129/1206-1'

data = np.loadtxt(dir+'/result_end2end.txt.prev',dtype='float')/1000000
x3 = np.sort(data[:49])
y3 = 1. * np.arange(len(x3))/(len(x3)-1)

x4 = np.sort(data[50:])
y4 = 1. * np.arange(len(x4))/(len(x4)-1)

# data = np.loadtxt(dir+'/result_inBro.txt.prev',dtype='float')/1000000
# x4 = np.sort(data)
# y4 = 1. * np.arange(len(data))/(len(data)-1)

#plot CDF
plt.figure(dpi=100)
plt.plot(x1, y1, label='QoS=0')
# plt.plot(x2, y2, label='QoS=0')
plt.plot(x3, y3, label='QoS=1')
# plt.plot(x4, y4, label='QoS=1')

plt.title("Small packets' end to end latency with different QoS")
plt.ylabel("Probability") # y label
plt.xlabel("latency (s)") # x labe

plt.legend(loc='lower right')

# %%
#cdf
import numpy as np
import matplotlib.pyplot as plt

dir='/home/maggie/mosq2.0.12/1129mosq_bro_time/z_exp/1129/1205-3/1205-3_all'

data = np.loadtxt(dir+'/end2end_all_S.txt',dtype='float')/1000000
x1 = np.sort(data)
y1 = 1. * np.arange(len(x1))/(len(x1)-1)

data = np.loadtxt(dir+'/end2end_all_L.txt',dtype='float')/1000000
x2 = np.sort(data)
y2 = 1. * np.arange(len(x2))/(len(x2)-1)

data = np.loadtxt(dir+'/inbro_all_S.txt',dtype='float')/1000000
x3 = np.sort(data)
y3 = 1. * np.arange(len(x3))/(len(x3)-1)

data = np.loadtxt(dir+'/inbro_all_L.txt',dtype='float')/1000000
x4 = np.sort(data)
y4 = 1. * np.arange(len(x4))/(len(x4)-1)


dir='/home/maggie/mosq2.0.12/1129mosq_bro_time/z_exp/1129/1205-4/1205-4_all'

data = np.loadtxt(dir+'/end2end_all_S.txt',dtype='float')/1000000
x5 = np.sort(data)
y5 = 1. * np.arange(len(x5))/(len(x5)-1)

data = np.loadtxt(dir+'/end2end_all_L.txt',dtype='float')/1000000
x6 = np.sort(data)
y6 = 1. * np.arange(len(x6))/(len(x6)-1)

data = np.loadtxt(dir+'/inbro_all_S.txt',dtype='float')/1000000
x7 = np.sort(data)
y7 = 1. * np.arange(len(x7))/(len(x7)-1)

data = np.loadtxt(dir+'/inbro_all_L.txt',dtype='float')/1000000
x8 = np.sort(data)
y8 = 1. * np.arange(len(x8))/(len(x8)-1)


#plot CDF
plt.figure(dpi=100)
plt.plot(x1, y1, label='Small, QoS=0')
plt.plot(x5, y5, label='Small, QoS=1')
plt.plot(x2, y2, label='Large, QoS=0')

plt.plot(x6, y6, label='Large, QoS=1')

plt.title("End-to-end latency with different QoS")
plt.ylabel("Probability") # y label
plt.xlabel("latency (s)") # x labe

plt.legend()

# %%
#cdf
import numpy as np
import matplotlib.pyplot as plt

dir='/home/maggie/mosq2.0.12/1129mosq_bro_time/z_exp/1129/1205-4'

y1 = np.loadtxt(dir+'/result_end2end.txt.prev',dtype='float')/1000000
x1 = np.arange(100)+1


y2 = np.loadtxt(dir+'/result_inBro.txt.prev',dtype='float')/1000000
x2 = np.arange(100)+1

#plot CDF
plt.figure(dpi=150)
plt.plot(x1[:50], y1[:50], label='end_to_end_S')
plt.plot(x1[:50], y1[50:], label='end_to_end_L')

plt.plot(x2[:50], y2[:50], label='in_bro_S')
plt.plot(x2[:50], y2[50:], label='in_bro_L')

plt.legend()
plt.show()
